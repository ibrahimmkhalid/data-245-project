# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
csv_path = './probe_known_attacks_small.csv'

# %%
df = pd.read_csv(csv_path, low_memory=False)

# %%
df.shape
# Out:
# (150634, 51)

# %%
df.columns
# Out:
# Index(['ip_type', 'ip_len', 'ip_id', 'ip_offset', 'ip_RF', 'ip_DF', 'ip_MF',
#        'ip_proto', 'ip_checksum', 'udp_sport', 'udp_dport', 'udp_len',
#        'udp_chk', 'icmp_type', 'icmp_code', 'icmp_chk', 'tcp_sport',
#        'tcp_dport', 'tcp_seq', 'tcp_ack', 'tcp_ffyn', 'tcp_fsyn', 'tcp_frst',
#        'tcp_fpush', 'tcp_fack', 'tcp_furg', 'fr_length', 'conn_status',
#        'count_fr_src_dst', 'count_fr_dst_src', 'count_serv_src_dst',
#        'count_serv_dst_src', 'num_bytes_src_dst', 'num_bytes_dst_src',
#        'num_bytes_serv_src_dst', 'num_bytes_serv_dst_src',
#        'num_pushed_src_dst', 'num_pushed_dst_src', 'num_syn_fin_src_dst',
#        'num_syn_fin_dst_src', 'num_fin_src_dst', 'num_fin_dst_src',
#        'num_ack_src_dst', 'num_ack_dst_src', 'num_syn_src_dst',
#        'num_syn_dst_src', 'num_rst_src_dst', 'num_rst_dst_src', 'first_packet',
#        'first_serv_packet', 'class'],
#       dtype='object')

# %%
df.head()
# Out:
#    ip_type  ip_len  ip_id  ip_offset  ip_RF  ip_DF  ip_MF  ip_proto  \
# 0        0      52  27414          0      0      1      0         6
# 1        0      52  11009          0      0      1      0         6
# 2        0      40  13967          0      0      0      0         6
# 3        0     552  13968          0      0      0      0         6
# 4        0     552  13969          0      0      0      0         6
#
#    ip_checksum  udp_sport  ...  num_fin_dst_src  num_ack_src_dst  \
# 0        19835          0  ...                0              415
# 1        36185          0  ...                1            11710
# 2        49623          0  ...                1            11710
# 3        49165          0  ...                0              415
# 4        49164          0  ...                0              415
#
#    num_ack_dst_src  num_syn_src_dst  num_syn_dst_src  num_rst_src_dst  \
# 0              578                1                1                0
# 1              408                2                2                0
# 2              409                2                2                0
# 3              579                1                1                0
# 4              580                1                1                0
#
#    num_rst_dst_src  first_packet  first_serv_packet   class
# 0                0             0                  0  normal
# 1                0             0                  0  normal
# 2                0             0                  0  normal
# 3                0             0                  0  normal
# 4                0             0                  0  normal
#
# [5 rows x 51 columns]

# %%
df.describe(include="all")
# Out:
#               ip_type         ip_len          ip_id  ip_offset     ip_RF  \
# count   150634.000000  150634.000000  150634.000000   150634.0  150634.0
# unique            NaN            NaN            NaN        NaN       NaN
# top               NaN            NaN            NaN        NaN       NaN
# freq              NaN            NaN            NaN        NaN       NaN
# mean         0.859248     151.344444   30713.499223        0.0       0.0
# std          6.060670     232.318030   20168.534898        0.0       0.0
# min          0.000000      28.000000       0.000000        0.0       0.0
# 25%          0.000000      40.000000   13196.000000        0.0       0.0
# 50%          0.000000      52.000000   30526.000000        0.0       0.0
# 75%          0.000000      93.000000   48214.000000        0.0       0.0
# max        192.000000    4183.000000   65535.000000        0.0       0.0
#
#                 ip_DF     ip_MF       ip_proto    ip_checksum      udp_sport  \
# count   150634.000000  150634.0  150634.000000  150634.000000  150634.000000
# unique            NaN       NaN            NaN            NaN            NaN
# top               NaN       NaN            NaN            NaN            NaN
# freq              NaN       NaN            NaN            NaN            NaN
# mean         0.361778       0.0       8.004428   33346.005809    6120.272568
# std          0.480516       0.0       4.446096   18664.459582   16549.560617
# min          0.000000       0.0       1.000000       0.000000       0.000000
# 25%          0.000000       0.0       6.000000   17373.000000       0.000000
# 50%          0.000000       0.0       6.000000   34741.000000       0.000000
# 75%          1.000000       0.0       6.000000   47208.000000       0.000000
# max          1.000000       0.0      17.000000   65534.000000   63399.000000
#
#         ...  num_fin_dst_src  num_ack_src_dst  num_ack_dst_src  \
# count   ...    150634.000000    150634.000000    150634.000000
# unique  ...              NaN              NaN              NaN
# top     ...              NaN              NaN              NaN
# freq    ...              NaN              NaN              NaN
# mean    ...        24.921339       191.632739       299.780740
# std     ...      1090.301407      1717.258546      1577.414872
# min     ...         0.000000         0.000000         0.000000
# 25%     ...         0.000000         1.000000         4.000000
# 50%     ...         0.000000        23.000000       120.000000
# 75%     ...         1.000000       190.000000       387.000000
# max     ...     65536.000000    130773.000000     84524.000000
#
#         num_syn_src_dst  num_syn_dst_src  num_rst_src_dst  num_rst_dst_src  \
# count     150634.000000    150634.000000    150634.000000    150634.000000
# unique              NaN              NaN              NaN              NaN
# top                 NaN              NaN              NaN              NaN
# freq                NaN              NaN              NaN              NaN
# mean          95.644463        39.504043        39.239494       102.518064
# std         1577.101433      1542.465671      1310.868678       735.301922
# min            0.000000         0.000000         0.000000         0.000000
# 25%            1.000000         0.000000         0.000000         0.000000
# 50%            1.000000         1.000000         0.000000         0.000000
# 75%            3.000000         2.000000         0.000000         4.000000
# max       131072.000000     95251.000000     65535.000000     65538.000000
#
#          first_packet  first_serv_packet   class
# count   150634.000000      150634.000000  150634
# unique            NaN                NaN       2
# top               NaN                NaN  normal
# freq              NaN                NaN  114006
# mean         0.003147           0.054218     NaN
# std          0.056007           0.226447     NaN
# min          0.000000           0.000000     NaN
# 25%          0.000000           0.000000     NaN
# 50%          0.000000           0.000000     NaN
# 75%          0.000000           0.000000     NaN
# max          1.000000           1.000000     NaN
#
# [11 rows x 51 columns]

# %% [markdown]
# It seems as though ip_RF, ip_MF, and ip_offset do not contain any valuable information. They can be removed

# %%
df = df.drop(columns=["ip_RF", "ip_MF", "ip_offset"])

# %%
df.columns
# Out:
# Index(['ip_type', 'ip_len', 'ip_id', 'ip_DF', 'ip_proto', 'ip_checksum',
#        'udp_sport', 'udp_dport', 'udp_len', 'udp_chk', 'icmp_type',
#        'icmp_code', 'icmp_chk', 'tcp_sport', 'tcp_dport', 'tcp_seq', 'tcp_ack',
#        'tcp_ffyn', 'tcp_fsyn', 'tcp_frst', 'tcp_fpush', 'tcp_fack', 'tcp_furg',
#        'fr_length', 'conn_status', 'count_fr_src_dst', 'count_fr_dst_src',
#        'count_serv_src_dst', 'count_serv_dst_src', 'num_bytes_src_dst',
#        'num_bytes_dst_src', 'num_bytes_serv_src_dst', 'num_bytes_serv_dst_src',
#        'num_pushed_src_dst', 'num_pushed_dst_src', 'num_syn_fin_src_dst',
#        'num_syn_fin_dst_src', 'num_fin_src_dst', 'num_fin_dst_src',
#        'num_ack_src_dst', 'num_ack_dst_src', 'num_syn_src_dst',
#        'num_syn_dst_src', 'num_rst_src_dst', 'num_rst_dst_src', 'first_packet',
#        'first_serv_packet', 'class'],
#       dtype='object')

# %%
df["class"].value_counts()
# Out:
# class
# normal    114006
# attack     36628
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# ip_type                    int64
# ip_len                     int64
# ip_id                      int64
# ip_DF                      int64
# ip_proto                   int64
# ip_checksum                int64
# udp_sport                  int64
# udp_dport                  int64
# udp_len                    int64
# udp_chk                    int64
# icmp_type                  int64
# icmp_code                  int64
# icmp_chk                   int64
# tcp_sport                  int64
# tcp_dport                  int64
# tcp_seq                    int64
# tcp_ack                    int64
# tcp_ffyn                   int64
# tcp_fsyn                   int64
# tcp_frst                   int64
# tcp_fpush                  int64
# tcp_fack                   int64
# tcp_furg                   int64
# fr_length                  int64
# conn_status                int64
# count_fr_src_dst           int64
# count_fr_dst_src           int64
# count_serv_src_dst         int64
# count_serv_dst_src         int64
# num_bytes_src_dst          int64
# num_bytes_dst_src          int64
# num_bytes_serv_src_dst     int64
# num_bytes_serv_dst_src     int64
# num_pushed_src_dst         int64
# num_pushed_dst_src         int64
# num_syn_fin_src_dst        int64
# num_syn_fin_dst_src        int64
# num_fin_src_dst            int64
# num_fin_dst_src            int64
# num_ack_src_dst            int64
# num_ack_dst_src            int64
# num_syn_src_dst            int64
# num_syn_dst_src            int64
# num_rst_src_dst            int64
# num_rst_dst_src            int64
# first_packet               int64
# first_serv_packet          int64
# class                     object
# dtype: object

# %%
df["ip_type"].value_counts()
# Out:
# ip_type
# 0      147459
# 40       3159
# 192        16
# Name: count, dtype: int64

# %%
df["class"] = df["class"].replace({"normal": 0, "attack": 1})

# %%
corr = df.corr()

# %%
plt.figure(figsize=(15, 12))
sns.heatmap(corr, cmap="Blues")
plt.show()

# %%
corr["class"].sort_values(ascending=False)
# Out:
# class                     1.000000
# tcp_sport                 0.397678
# first_serv_packet         0.325504
# tcp_fsyn                  0.155948
# udp_sport                 0.153468
# tcp_ffyn                  0.150775
# num_rst_dst_src           0.116606
# tcp_furg                  0.066456
# ip_id                     0.057978
# tcp_fpush                 0.056084
# ip_proto                  0.049438
# udp_chk                   0.036507
# num_syn_fin_dst_src       0.028898
# num_syn_src_dst           0.021685
# udp_dport                 0.017757
# num_fin_src_dst           0.012712
# count_fr_dst_src          0.007803
# num_syn_fin_src_dst       0.007382
# num_pushed_src_dst       -0.003894
# num_pushed_dst_src       -0.005051
# num_rst_src_dst          -0.006449
# num_fin_dst_src          -0.007466
# count_serv_src_dst       -0.009019
# num_syn_dst_src          -0.013193
# count_fr_src_dst         -0.018055
# ip_checksum              -0.018142
# first_packet             -0.018860
# num_ack_dst_src          -0.032619
# num_ack_src_dst          -0.043987
# count_serv_dst_src       -0.048148
# icmp_type                -0.056976
# tcp_frst                 -0.063606
# ip_type                  -0.072517
# tcp_seq                  -0.073762
# icmp_chk                 -0.075783
# icmp_code                -0.081449
# num_bytes_serv_src_dst   -0.167923
# udp_len                  -0.194222
# ip_DF                    -0.196617
# conn_status              -0.220197
# num_bytes_src_dst        -0.221637
# fr_length                -0.255816
# ip_len                   -0.267105
# tcp_dport                -0.295696
# tcp_ack                  -0.392178
# tcp_fack                 -0.409585
# num_bytes_serv_dst_src   -0.441665
# num_bytes_dst_src        -0.454198
# Name: class, dtype: float64

# %% [markdown]
# The target feature does not seem to have very strong correlations with any particular feature.
