# %%
import pandas as pd
pd.set_option("display.width", 10000)
pd.set_option("display.max_rows", 500)
pd.set_option("display.max_columns", 500)
pd.set_option("display.max_colwidth", None)

# %%
local_df = pd.read_csv("./benchmark_results.csv")
colab_df = pd.read_csv("./benchmark_results_colab.csv")

# %%
local_df
# Out:
#                                                     Model          Dataset                                          Info  Data size  Accuracy  Precision    Recall        F1  Time per data per iter
# 0   SVM {'C': 10000.0, 'gamma': 'scale', 'kernel': 'rbf'}    Known attacks           |correlation| > 0.1 features scaled      17012  0.997708   0.999593  0.995142  0.997363                0.000107
# 1    SVM {'C': 1000.0, 'gamma': 'scale', 'kernel': 'rbf'}    Known attacks                           All features scaled      17012  0.997649   0.996899  0.997706  0.997302                0.000118
# 2     SVM {'C': 1000.0, 'gamma': 'auto', 'kernel': 'rbf'}    Known attacks                       PCA 95% on all features      17012  0.997237   0.995959  0.997706  0.996832                0.000138
# 3      SVM {'C': 10.0, 'gamma': 'scale', 'kernel': 'rbf'}    Known attacks  PCA 95% on features with |correlation| > 0.1      17012  1.000000   1.000000  1.000000  1.000000                0.000077
# 4    SVM {'C': 1000.0, 'gamma': 'scale', 'kernel': 'rbf'}  Similar attacks                           All features scaled      26409  0.989208   0.994738  0.977874  0.986234                0.000115
# 5     SVM {'C': 1000.0, 'gamma': 'auto', 'kernel': 'rbf'}  Similar attacks                       PCA 95% on all features      26409  0.990609   0.996977  0.979215  0.988016                0.000120
# 6   SVM {'C': 10000.0, 'gamma': 'scale', 'kernel': 'rbf'}  Similar attacks           |correlation| > 0.1 features scaled      26409  0.964255   0.946660  0.963889  0.955197                0.000100
# 7      SVM {'C': 10.0, 'gamma': 'scale', 'kernel': 'rbf'}  Similar attacks  PCA 95% on features with |correlation| > 0.1      26409  0.999205   1.000000  0.997989  0.998993                0.000085
# 8    SVM {'C': 1000.0, 'gamma': 'scale', 'kernel': 'rbf'}      New attacks                           All features scaled      75890  0.766372   0.570513  0.005014  0.009940                0.000121
# 9     SVM {'C': 1000.0, 'gamma': 'auto', 'kernel': 'rbf'}      New attacks                       PCA 95% on all features      75890  0.765898   0.492424  0.025631  0.048726                0.000147
# 10  SVM {'C': 10000.0, 'gamma': 'scale', 'kernel': 'rbf'}      New attacks           |correlation| > 0.1 features scaled      75890  0.769179   0.506935  0.483833  0.495115                0.000120
# 11     SVM {'C': 10.0, 'gamma': 'scale', 'kernel': 'rbf'}      New attacks  PCA 95% on features with |correlation| > 0.1      75890  0.999526   1.000000  0.997972  0.998985                0.000095

# %%
colab_df
# Out:
#                                                      Model          Dataset                                          Info  Data size  Accuracy  Precision    Recall        F1  Time per data per iter
# 0   SVM {'C': 10000.0, 'gamma': 'scale', 'kernel': 'poly'}    Known attacks           |correlation| > 0.1 features scaled      17012  0.997472   0.998781  0.995412  0.997094                0.001615
# 1    SVM {'C': 1000.0, 'gamma': 'scale', 'kernel': 'poly'}    Known attacks                           All features scaled      17012  0.997590   0.997033  0.997436  0.997234                0.001651
# 2     SVM {'C': 1000.0, 'gamma': 'auto', 'kernel': 'poly'}    Known attacks                       PCA 95% on all features      17012  0.996297   0.995282  0.996222  0.995752                0.001667
# 3      SVM {'C': 10.0, 'gamma': 'scale', 'kernel': 'poly'}    Known attacks  PCA 95% on features with |correlation| > 0.1      17012  1.000000   1.000000  1.000000  1.000000                0.001639
# 4    SVM {'C': 1000.0, 'gamma': 'scale', 'kernel': 'poly'}  Similar attacks                           All features scaled      26409  0.991177   0.995919  0.981705  0.988761                0.001655
# 5     SVM {'C': 1000.0, 'gamma': 'auto', 'kernel': 'poly'}  Similar attacks                       PCA 95% on all features      26409  0.990193   0.994367  0.980747  0.987510                0.001662
# 6   SVM {'C': 10000.0, 'gamma': 'scale', 'kernel': 'poly'}  Similar attacks           |correlation| > 0.1 features scaled      26409  0.922564   0.965820  0.833621  0.894864                0.001657
# 7      SVM {'C': 10.0, 'gamma': 'scale', 'kernel': 'poly'}  Similar attacks  PCA 95% on features with |correlation| > 0.1      26409  1.000000   1.000000  1.000000  1.000000                0.001644
# 8    SVM {'C': 1000.0, 'gamma': 'scale', 'kernel': 'poly'}      New attacks                           All features scaled      75890  0.773185   0.773604  0.042925  0.081336                0.001657
# 9     SVM {'C': 1000.0, 'gamma': 'auto', 'kernel': 'poly'}      New attacks                       PCA 95% on all features      75890  0.768112   0.566379  0.037010  0.069480                0.001658
# 10  SVM {'C': 10000.0, 'gamma': 'scale', 'kernel': 'poly'}      New attacks           |correlation| > 0.1 features scaled      75890  0.794215   0.557725  0.581005  0.569127                0.001657
# 11     SVM {'C': 10.0, 'gamma': 'scale', 'kernel': 'poly'}      New attacks  PCA 95% on features with |correlation| > 0.1      75890  0.995045   1.000000  0.978819  0.989296                0.001642
